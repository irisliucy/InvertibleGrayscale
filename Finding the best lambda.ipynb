# %% [markdown]
# ### Finding the best lambda for L2 regularization

# %%
import tensorflow as tf
import csv
import os, sys
import math

from config import *
from model import *
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ### 1. Performance of model (MSE) against the lamda value

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')
plt.figure(figsize=(10,7))

plt.subplot(2,3,1)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1], 
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [31.51, 52.94, 73.15, 98.52, 145.40, 506.18, 318.67, 508.23], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 0, 550])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.1',
         pad=10)

# plt.show()

#####################
plt.subplot(2,3,2)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5],
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [66.72, 62.54, 107.83, 106.02, 152.34, 507.64, 321.67, 509.02], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 0, 550])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.2',
         pad=10)

# plt.show()
######################
plt.subplot(2,3,3)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1], 
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [118.91, 78.62, 149.32, 118.19, 164.13, 510.16, 326.4, 509.70], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 0, 550])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.3',
         pad=10)

# plt.show()
########################
plt.subplot(2,3,4)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1], 
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [184.53, 100.52,197.06, 134.51,180.62, 514.59, 333.03, 510.08], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 0, 550])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.4',
         pad=10)

# plt.show()
##########################
plt.subplot(2,3,5)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1], 
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [263.89, 128.55, 253.5, 154.00, 202.47, 520.10, 341.36, 511.51], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 0, 550])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.5',
         pad=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Performance of model (PSNR) against the lamda value

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')
plt.figure(figsize=(10,7))

plt.subplot(2,3,1)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1], 
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [33.73, 31.69, 30.27, 28.76, 27.28, 21.78, 23.75, 21.76], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 20, 40])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.1',
         pad=10)

# plt.show()

#####################
plt.subplot(2,3,2)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5],
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [30.89, 31.01, 28.75, 28.5, 27.09, 21.76, 23.72, 21.76], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 20, 40])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.2',
         pad=10)

# plt.show()
######################
plt.subplot(2,3,3)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1], 
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [28.56, 30.07, 27.37, 28.13, 26.81, 21.75, 23.64, 21.74], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 20, 40])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.3',
         pad=10)

# plt.show()
########################
plt.subplot(2,3,4)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1], 
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [26.73, 29.04,26.14, 27.68,26.45, 21.71, 23.563, 21.74], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 20, 40])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.4',
         pad=10)

# plt.show()
##########################
plt.subplot(2,3,5)
# plt.plot([0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1], 
plt.plot([-4, -3.3, -3, -2.3, -2, -1.3, -1, -0.3], 
        [25.19, 28.01, 25.03, 27.20, 26.05, 21.67, 23.45, 21.73], 
         'b.-',
         label='VGG19- L2 regualrization')
plt.axis([-5, 0, 20, 40])
plt.legend(loc='lower right')
plt.xlabel('log(lambda)')
plt.ylabel('Test Set MSE')
plt.title('σ=0.5',
         pad=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Average test set MSE  of VGG19 - l2 regularized over 20 trials, σ=0.1
#
# |Lambda| MSE | PSNR |
# |:------|:-------------|:-------------|
# |0.0001| 31.51 | 33.73|
# |0.0005| 52.94 | 31.69 |
# |0.001| 73.15| 30.27 |
# |0.005| 98.52| 28.76 |
# |0.01| 145.40| 27.28 |
# |0.05| 506.18| 21.78 |
# |0.1| 318.67| 23.75 |
# |0.5| 508.23| 21.76|

# %% [markdown]
# #### Average test set MSE  of VGG19 - l2 regularized over 20 trials, σ=0.2
#
# |Lambda| MSE | PSNR |
# |:------|:-------------|:-------------|
# |0.0001| 66.72 | 30.89|
# |0.0005| 62.54 | 31.01 |
# |0.001| 107.83| 28.75 |
# |0.005| 106.02| 28.50 |
# |0.01| 152.34| 27.09|
# |0.05| 507.64| 21.76 |
# |0.1| 321.67| 23.72 |
# |0.5| 509.02| 21.76 |

# %% [markdown]
# #### Average test set MSE  of VGG19 - l2 regularized over 20 trials, σ=0.3
#
# |Lambda| MSE | PSNR |
# |:------|:-------------|:-------------|
# |0.0001| 118.91 | 28.56 |
# |0.0005| 78.62 | 30.07 |
# |0.001| 149.32| 27.37 |
# |0.005| 118.19| 28.13|
# |0.01| 164.13| 26.81 |
# |0.05| 510.16| 21.75 |
# |0.1| 326.40 | 23.64 |
# |0.5| 509.70| 21.74 |

# %% [markdown]
# #### Average test set MSE  of VGG19 - l2 regularized over 20 trials, σ=0.4
#
# |Lambda| MSE | PSNR |
# |:------|:-------------|:-------------|
# |0.0001| 184.53 | 26.73 |
# |0.0005| 100.52 | 29.04 |
# |0.001| 197.06| 26.14 |
# |0.005| 134.51| 27.68 |
# |0.01| 180.62| 26.45 |
# |0.05| 514.59| 21.71 |
# |0.1| 333.033| 23.56|
# |0.5| 510.08| 21.74 |

# %% [markdown]
# #### Average test set MSE  of VGG19 - l2 regularized over 20 trials, σ=0.5
#
# |Lambda| MSE | PSNR |
# |:------|:-------------|:-------------|
# |0.0001| 263.89 | 25.19 |
# |0.0005| 128.55 | 28.01 |
# |0.001| 253.50| 25.03 |
# |0.005| 154.00| 27.20 |
# |0.01| 202.47| 26.05 |
# |0.05| 520.10| 21.67 |
# |0.1| 341.36| 23.45 |
# |0.5| 511.51| 21.73|
